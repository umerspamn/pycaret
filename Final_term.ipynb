# %% [markdown]
# <a href="https://colab.research.google.com/github/umerspamn/pycaret/blob/main/Final_term.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1a) Overfitting occurs when a machine learning model learns the training data too well, capturing noise and random fluctuations in the data instead of the underlying pattern. To avoid overfitting, techniques like cross-validation, regularization, and using more data are employed.

# %%
#1b)The bias-variance tradeoff refers to the balance between the bias of the model and its variance. A model with high bias pays little attention to the training data and oversimplifies the problem (underfitting), while a model with high variance learns the training data too well and performs poorly on unseen data (overfitting). Finding the right balance between bias and variance is crucial for building a model that generalizes well.

# %%
#1c)Classification is used when the target variable is categorical, meaning it belongs to a finite set of classes or categories. Regression, on the other hand, is used when the target variable is continuous, such as predicting prices, temperatures, or quantities. You would use classification when you want to predict discrete outcomes, like whether an email is spam or not, or whether a customer will churn or not.

# %%
#2a)Cross-validation is a technique used to assess how well a model will generalize to an independent data set. It involves partitioning the data into subsets, training the model on a subset, and then evaluating it on the remaining subset. This process is repeated multiple times, and the performance metrics are averaged to get a more reliable estimate of the model's performance.

# %%
#2b)The F1 score is the harmonic mean of precision and recall. It provides a balance between precision
#Precision = ����+��=3535+5=0.875TP+FPTP​=35+535​=0.875
#Recall = ����+��=3535+10=0.778TP+FNTP​=35+1035​=0.778
�1=2×0.875×0.7780.875+0.778=0.824#F1=0.875+0.7782×0.875×0.778​=0.824
# Out:
#   File "<ipython-input-5-391564963456>", line 4
#     �1=2×0.875×0.7780.875+0.778=0.824#F1=0.875+0.7782×0.875×0.778​=0.824
#     ^
# SyntaxError: invalid character '�' (U+FFFD)

# %%
import pandas as pd

df=pd.read_csv("loan_data.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001003    Male     Yes          1      Graduate            No
# 1    LP001005    Male     Yes          0      Graduate           Yes
# 2    LP001006    Male     Yes          0  Not Graduate            No
# 3    LP001008    Male      No          0      Graduate            No
# 4    LP001013    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 376  LP002953    Male     Yes         3+      Graduate            No
# 377  LP002974    Male     Yes          0      Graduate            No
# 378  LP002978  Female      No          0      Graduate            No
# 379  LP002979    Male     Yes         3+      Graduate            No
# 380  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# !pip install pycaret
import pandas as pd
from pycaret.classification import *
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.9/485.9 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 49.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 16.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.7/257.7 kB 24.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.9/21.9 MB 30.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 72.1 MB/s eta 0:00:00
# ...

# %%
# Drop non-numeric columns
data.drop(columns=['Loan_ID'], inplace=True)

# Handle missing values
data.fillna(method='ffill', inplace=True)  # Forward fill missing values

# Initialize PyCaret setup with proper categorical encoding
clf = setup(data, target='Loan_Status', train_size=0.8, normalize=True, categorical_features=['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Credit_History', 'Property_Area'])

# Proceed with the rest of the code...
# Out:
# <style type="text/css">
# #T_136fd_row10_col1, #T_136fd_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_136fd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_136fd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_136fd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_136fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_136fd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_136fd_row0_col1" class="data row0 col1" >227</td>
#     </tr>
#     <tr>
#       <th id="T_136fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_136fd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_136fd_row1_col1" class="data row1 col1" >Loan_Status</td>
#     </tr>
#     <tr>
# ...

# %%
best_model = compare_models(fold=5)
# Out:
# <style type="text/css">
# #T_1ea2c th {
#   text-align: left;
# }
# ...

# %%
tuned_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_d2a8c_row10_col0, #T_d2a8c_row10_col1, #T_d2a8c_row10_col2, #T_d2a8c_row10_col3, #T_d2a8c_row10_col4, #T_d2a8c_row10_col5, #T_d2a8c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d2a8c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2a8c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d2a8c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d2a8c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d2a8c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d2a8c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d2a8c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d2a8c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
plot_model(tuned_model, plot='confusion_matrix')

# %%
plot_model(tuned_model, plot='class_report')

# %%
final_model = finalize_model(tuned_model)

# %%
save_model(final_model, 'loan_approval_prediction_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['ApplicantIncome',
#                                               'CoapplicantIncome', 'LoanAmount',
#                                               'Loan_Amount_Term'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=No...
#                                                                return_df=True,
# ...

# %% [markdown]
# # New Section
